# %%
with open('words.txt','r') as my_file: 
    words = {} # initialize a dictionary 
    for word in my_file: 
        word = word.strip() 
        value = list(word) 
        value.sort() 
        if (word in words): # add words to the dictionary 
            words[word] = value 
        else: 
            words[word] = value

def largesttenAnagram(words):
    
    import collections
    d = collections.defaultdict(list)
    for word in words:
        sortedWord = str(sorted(word))
        d[ hash(sortedWord) ].append(word)
    
    maxKey = max( d.keys(), key = lambda k : len(d[k]) )
    count =0
    keys = [(len(v), k) for k, v in d.items() if len(v) > 1]
    keys.sort(reverse=True)
    for _, k in keys:
        print(d[k])
        del d[k]
        if count ==9:
            break
        count = count+1
    #return d[maxKey]

# %%
# %%time
ter = wordIterator( 'words.txt' )
largesttenAnagram(ter)
# Out:
# [(11, 8203625738376484219), (11, 139682231701306928), (10, -1042293001494854342), (9, 1328304088648956023), (9, -4714620331795312443), (8, 7326739515802764761), (8, 7203849626184633872), (8, 4828849061916195792), (8, 4357431890459378898), (8, 1577609390777384448), (8, -158704755470591115), (8, -2970464893677844870), (8, -3676479047145941802), (8, -7845447740610066268), (8, -8655214987374702976), (7, 8828321167325364531), (7, 8743422907019244818), (7, 6451100907814267699), (7, 4548562118418080264), (7, 2977702277654259760), (7, 2349559308178695134), (7, 1800839028981556609), (7, 1436183438195926755), (7, 1057243236508406198), (7, 39912085403488488), (7, -242128749549306924), (7, -1041232650076486432), (7, -1531290204999853039), (7, -1653330099683864230), (7, -1892369640280767423), (7, -2010767866847438077), (7, -2636696771874677975), (7, -3360618912679745080), (7, -3895844544315561866), (7, -4191372995182678118), (7, -4840721751933777685), (7, -5679319465684191348), (7, -5906904449396
# ...

# %%
# %%time
ter = wordIterator( 'words.txt' )
largestAnagram(ter)
# Out:
# ['alerts', 'alters', 'artels', 'estral', 'laster', 'ratels', 'salter', 'slater', 'staler', 'stelar', 'talers']
# ['apers', 'asper', 'pares', 'parse', 'pears', 'prase', 'presa', 'rapes', 'reaps', 'spare', 'spear']
# ['least', 'setal', 'slate', 'stale', 'steal', 'stela', 'taels', 'tales', 'teals', 'tesla']
# ['capers', 'crapes', 'escarp', 'pacers', 'parsec', 'recaps', 'scrape', 'secpar', 'spacer']
# ['estrin', 'inerts', 'insert', 'inters', 'niters', 'nitres', 'sinter', 'triens', 'trines']
# ['acers', 'acres', 'cares', 'carse', 'escar', 'races', 'scare', 'serac']
# ['anestri', 'nastier', 'ratines', 'retains', 'retinas', 'retsina', 'stainer', 'stearin']
# ['arles', 'earls', 'lares', 'laser', 'lears', 'rales', 'reals', 'seral']
# ['aspers', 'parses', 'passer', 'prases', 'repass', 'spares', 'sparse', 'spears']
# ['ates', 'east', 'eats', 'etas', 'sate', 'seat', 'seta', 'teas']
# CPU times: user 1.11 s, sys: 27 ms, total: 1.14 s
# Wall time: 1.16 s
